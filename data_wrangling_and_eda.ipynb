# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing the dataset and explore it

# %%
"""
data_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(data_path, header=None)
"""
# Out:
# '\ndata_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"\ndf = pd.read_csv(data_path, header=None)\n'

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# %%
df = pd.read_csv("Cars_price.csv",names = headers)

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          0                 1            2         3          4            5
# 1          3                 ?  alfa-romero       gas        std          two
# 2          3                 ?  alfa-romero       gas        std          two
# 3          1                 ?  alfa-romero       gas        std          two
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0            6            7               8         9.0  ...           16
# 1  convertible          rwd           front        88.6  ...          130
# 2  convertible          rwd           front        88.6  ...          130
# 3    hatchback          rwd           front        94.5  ...          152
# 4        sedan          fwd           front        99.8  ...          109
#
# ...

# %%
# remove the first line of data which correspond columns number
df.drop([0],axis = 0, inplace = True)
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 1          3                 ?  alfa-romero       gas        std          two
# 2          3                 ?  alfa-romero       gas        std          two
# 3          1                 ?  alfa-romero       gas        std          two
# 4          2               164         audi       gas        std         four
# 5          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 1  convertible          rwd           front        88.6  ...          130
# 2  convertible          rwd           front        88.6  ...          130
# 3    hatchback          rwd           front        94.5  ...          152
# 4        sedan          fwd           front        99.8  ...          109
# 5        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
# discover the null values used in this dataset
""" "make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"
"""
print(df["symboling"].value_counts())
"""
print("\n\n ",df["normalized-losses"].value_counts())
print("\n\n ",df["make"].value_counts())
print("\n\n ",df["fuel-type"].value_counts())
print("\n\n ",df["aspiration"].value_counts())
print("\n\n ",df["num-of-doors"].value_counts())
print("\n\n ",df["body-style"].value_counts())
print("\n\n ",df["drive-wheels"].value_counts())
print("\n\n ",df["engine-location"].value_counts())
print("\n\n ",df["wheel-base"].value_counts())
print("\n\n ",df["length"].value_counts())
print("\n\n ",df["width"].value_counts())
print("\n\n ",df["height"].value_counts())
print("\n\n ",df["curb-weight"].value_counts())
print("\n\n ",df["engine-type"].value_counts())
print("\n\n ",df["num-of-cylinders"].value_counts())
print("\n\n ",df["engine-size"].value_counts())
print("\n\n ",df["fuel-system"].value_counts())
print("\n\n ",df["bore"].value_counts())
print("\n\n ",df["stroke"].value_counts())
print("\n\n ",df["compression-ratio"].value_counts())
print("\n\n ",df["horsepower"].value_counts())
print("\n\n ",df["peak-rpm"].value_counts())
print("\n\n ",df["city-mpg"].value_counts())
print("\n\n ",df["highway-mpg"].value_counts())
print("\n\n ",df["price"].value_counts())
"""
# Out:
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: symboling, dtype: int64
# ...

# %%
# after checking all columns i find that the missing data is representated by ?
# we are gonna replace the missing value by nan. so we can use the predefined methodes on pandas
# replace ? by nan
df.replace("?", np.nan, inplace = True)

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
# for the numbers we gonna replace it by the mean 
normalized_losses_mean = df["normalized-losses"].astype("float64").mean()
bore_mean = df["bore"].astype("float64").mean()
stroke_mean = df["stroke"].astype("float64").mean()
horsepower_mean = df["horsepower"].astype("float64").mean()
peak_rpm_mean = df["peak-rpm"].astype("float64").mean()

# replace the missing value by the mean
df["normalized-losses"].replace(np.nan, normalized_losses_mean, inplace = True)
df["bore"].replace(np.nan, bore_mean, inplace = True)
df["stroke"].replace(np.nan, normalized_losses_mean, inplace = True)
df["horsepower"].replace(np.nan, horsepower_mean, inplace = True)
df["peak-rpm"].replace(np.nan, peak_rpm_mean, inplace = True)

# %%
df[df["num-of-doors"].isnull()]
# Out:
#     symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 28          1               148  dodge       gas      turbo          NaN
# 64          0             122.0  mazda    diesel        std          NaN
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 28      sedan          fwd           front        93.7  ...           98
# 64      sedan          fwd           front        98.8  ...          122
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 28         mpfi  3.03    3.39               7.6        102      5500       24
# 64          idi  3.39    3.39              22.7         64      4650       36
#
#    highway-mpg  price
# 28          30   8558
# 64          42  10795
#
# [2 rows x 26 columns]

# %%
# for the categorical variable we gonna replace it by the most frequent
# as we can see 84% oft the cars with a body-type sedan have four doors 
df_sedan = df[df["body-style"] == "sedan"]
df_sedan = df_sedan[df_sedan["num-of-doors"].notnull()]
(df_sedan[df_sedan["num-of-doors"].notnull()]["num-of-doors"].value_counts()/df_sedan.shape[0]) * 100
# Out:
# four    84.042553
# two     15.957447
# Name: num-of-doors, dtype: float64

# %%
# we gonna to replace the missing value
df["num-of-doors"].replace(np.nan, "four", inplace = True)

# %%
# for the missing value of the price we can't do nothing because it's the predicted variable
# so we gonna to drop those instances
df.dropna(subset = ["price"], axis = 0, inplace = True)
df.reset_index(drop=True, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    object
#  2   make               201 non-null    object
#  3   fuel-type          201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num-of-doors       201 non-null    object
#  6   body-style         201 non-null    object
#  7   drive-wheels       201 non-null    object
#  8   engine-location    201 non-null    object
#  9   wheel-base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    int64
#  14  engine-type        201 non-null    object
#  15  num-of-cylinders   201 non-null    object
# ...

# %%
# change the type of data
df[["normalized-losses", "horsepower", "peak-rpm", "price"]] = df[["normalized-losses", "horsepower", "peak-rpm", "price"]].astype("int64")
df[["bore", "stroke"]] = df[["bore", "stroke"]].astype("float64")
df["symboling"] = df["symboling"].astype("object")

# %%
df.dtypes
# Out:
# symboling             object
# normalized-losses      int64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower             int64
# peak-rpm               int64
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
# check for duplication
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized-losses, make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, engine-location, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# # data analysis

# %%
df.corr()
# Out:
#                    normalized-losses  wheel-base    length     width  \
# normalized-losses           1.000000   -0.056661  0.019424  0.086802
# wheel-base                 -0.056661    1.000000  0.876024  0.814507
# length                      0.019424    0.876024  1.000000  0.857170
# width                       0.086802    0.814507  0.857170  1.000000
# height                     -0.373737    0.590742  0.492063  0.306002
# curb-weight                 0.099404    0.782097  0.880665  0.866201
# engine-size                 0.112360    0.572027  0.685025  0.729436
# bore                       -0.029862    0.493244  0.608971  0.544885
# stroke                      0.126034   -0.079330 -0.057929 -0.009260
# compression-ratio          -0.114713    0.250313  0.159733  0.189867
# horsepower                  0.217300    0.371178  0.579795  0.615056
# peak-rpm                    0.239544   -0.360301 -0.285973 -0.245803
# city-mpg                   -0.225016   -0.470606 -0.665192 -0.633531
# ...

# %%
plt.subplots(figsize=(15,12))
ax = sns.heatmap(df.corr(),annot=True, vmin=-1, vmax=1, cmap ="coolwarm")
plt.title("Data correlation", fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})
plt.show()

# %% [markdown]
# ### since we are dealing with a few number of instance it will hard to train a model effectively because we will be suffering of a overfiting we are going to create a new column named size = length of the car multiply by width

# %%
df = df.assign(size=df["length"]*df["width"])
df = df[df.columns[:-2].to_list()+['size','price']]
df.drop(['length', 'width'], axis=1, inplace = True)

# %%
df.describe(include=['object'])
# Out:
#         symboling    make fuel-type aspiration num-of-doors body-style  \
# count         201     201       201        201          201        201
# unique          6      22         2          2            2          5
# top             0  toyota       gas        std         four      sedan
# freq           65      32       181        165          115         94
#
#        drive-wheels engine-location engine-type num-of-cylinders fuel-system
# count           201             201         201              201         201
# unique            3               2           6                7           8
# top             fwd           front         ohc             four        mpfi
# freq            118             198         145              157          92

# %%
# this function is used to draw the boxplot and the density for numerical variables
def numerical_plotting(df, col, title, symb):
    fig, ax = plt.subplots(2, 1, figsize=(10,7),gridspec_kw={"height_ratios": (.2, .8)})
    ax[0].set_title(title,fontsize=18)
    sns.boxplot(x=col, data=df, ax=ax[0])
    ax[0].set(yticks=[])
    sns.distplot(df[col],kde=True)
    plt.xticks(rotation=45)
    ax[1].set_xlabel(col, fontsize=16)
    plt.axvline(df[col].mean(), color='darkgreen', linewidth=3, label='mean=' + str(np.round(df[col].mean(),1)) + symb)
    plt.axvline(df[col].median(), color='red', linewidth=3, label='median='+ str(np.round(df[col].median(),1)) + symb)
    plt.axvline(df[col].mode()[0], color='purple', linewidth=3, label='mode='+ str(df[col].mode()[0]) + symb)
    plt.legend(bbox_to_anchor=(1, 1.03), ncol=1, fontsize=17, fancybox=True, shadow=True, frameon=True)
    plt.tight_layout()
    plt.show()

# %%
numerical_plotting(df,'price','price Distribution',' $')
# Out:
# C:\Users\LENOVO THINKPAD X260\AppData\Roaming\Python\Python38\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Showing some statistics about the price such as max min ..etc
df[["price"]].describe().T
# Out:
#        count          mean          std     min     25%      50%      75%  \
# price  201.0  13207.129353  7947.066342  5118.0  7775.0  10295.0  16500.0
#
#            max
# price  45400.0

# %%
# getting the instances with max and the min price
df[(df["price"] == 5118) | (df["price"] == 45400)]
# Out:
#     symboling  normalized-losses           make fuel-type aspiration  \
# 71          1                122  mercedes-benz       gas        std
# 134         2                 83         subaru       gas        std
#
#     num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# 71           two    hardtop          rwd           front       112.0  ...
# 134          two  hatchback          fwd           front        93.7  ...
#
#      fuel-system  bore stroke compression-ratio  horsepower peak-rpm  \
# 71          mpfi  3.80   3.35               8.0         184     4500
# 134         2bbl  3.62   2.36               9.0          69     4900
#
#      city-mpg  highway-mpg      size  price
# 71         14           16  14342.40  45400
# 134        31           36   9947.46   5118
#
# [2 rows x 25 columns]

# %% [markdown]
# ## we are going to look at the vars who have the higher (positve or negative) correlation with price

# %% [markdown]
# ### Engine-size

# %%
# let's begin with the engine-size
# As the engine-size goes up, the price goes up: this indicates a positive direct correlation
# the engine-size seems like a good predictor. specially since the regression line is almost a diagonal line
sns.regplot(x="engine-size", y="price", data=df)
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='price'>

# %%
# the engine-size have the highest correlation factor 
df[["engine-size","price"]].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
# looking at the engine-size data distribution
numerical_plotting(df,'engine-size','engine-size Distribution','')
# Out:
# C:\Users\LENOVO THINKPAD X260\AppData\Roaming\Python\Python38\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df[["engine-size"]].describe().T
# Out:
#              count        mean        std   min   25%    50%    75%    max
# engine-size  201.0  126.875622  41.546834  61.0  98.0  120.0  141.0  326.0

# %%
# getting the instances with max and the min price
df[(df["engine-size"] == df["engine-size"].min()) | (df["engine-size"] == df["engine-size"].max())]
# Out:
#    symboling  normalized-losses       make fuel-type aspiration num-of-doors  \
# 17         2                121  chevrolet       gas        std          two
# 46         0                122     jaguar       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  fuel-system  \
# 17  hatchback          fwd           front        88.4  ...         2bbl
# 46      sedan          rwd           front       102.0  ...         mpfi
#
#     bore stroke compression-ratio  horsepower peak-rpm  city-mpg  highway-mpg  \
# 17  2.91   3.03               9.5          48     5100        47           53
# 46  3.54   2.76              11.5         262     5000        13           17
#
#         size  price
# 17   8508.33   5151
# 46  13534.02  36000
#
# [2 rows x 25 columns]

# %% [markdown]
# ### curb-weight

# %%
# As the curb-weight goes up, the price goes up: this indicates a positive direct correlation
# the curb-weight is also seems like a good predictor.
sns.regplot(x="curb-weight", y="price", data=df)
# Out:
# <AxesSubplot:xlabel='curb-weight', ylabel='price'>

# %%
# the curb-weight the seconde highest correlation factor 
df[["curb-weight","price"]].corr()
# Out:
#              curb-weight     price
# curb-weight     1.000000  0.834415
# price           0.834415  1.000000

# %%
# looking at the curb-weight data distribution
numerical_plotting(df,'curb-weight','curb-weight Distribution','')
# Out:
# C:\Users\LENOVO THINKPAD X260\AppData\Roaming\Python\Python38\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df[["curb-weight"]].describe().T
# Out:
#              count         mean         std     min     25%     50%     75%  \
# curb-weight  201.0  2555.666667  517.296727  1488.0  2169.0  2414.0  2926.0
#
#                 max
# curb-weight  4066.0

# %%
# getting the instances with max and the min price
df[(df["curb-weight"] == df["curb-weight"].min()) | (df["curb-weight"] == df["curb-weight"].max())]
# Out:
#    symboling  normalized-losses       make fuel-type aspiration num-of-doors  \
# 17         2                121  chevrolet       gas        std          two
# 44         0                145     jaguar       gas        std         four
# 45         0                122     jaguar       gas        std         four
#
#    body-style drive-wheels engine-location  wheel-base  ...  fuel-system  \
# 17  hatchback          fwd           front        88.4  ...         2bbl
# 44      sedan          rwd           front       113.0  ...         mpfi
# 45      sedan          rwd           front       113.0  ...         mpfi
#
#     bore stroke compression-ratio  horsepower peak-rpm  city-mpg  highway-mpg  \
# 17  2.91   3.03               9.5          48     5100        47           53
# 44  3.63   4.17               8.1         176     4750        15           19
# 45  3.63   4.17               8.1         176     4750        15           19
#
#         size  price
# 17   8508.33   5151
# ...

# %% [markdown]
# ### Horsepower

# %%
# As the horsepower goes up, the price goes up: this indicates a positive direct correlation
# the horsepower is also seems like a good predictor.
sns.regplot(x="horsepower", y="price", data=df)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='price'>

# %%
# the horsepower the third highest correlation factor 
df[["horsepower","price"]].corr()
# Out:
#             horsepower     price
# horsepower    1.000000  0.809607
# price         0.809607  1.000000

# %%
df[["horsepower"]].describe().T
# Out:
#             count        mean       std   min   25%   50%    75%    max
# horsepower  201.0  103.402985  37.36565  48.0  70.0  95.0  116.0  262.0

# %%
# looking at the horsepower data distribution
numerical_plotting(df,'horsepower','horsepower Distribution','')
# Out:
# C:\Users\LENOVO THINKPAD X260\AppData\Roaming\Python\Python38\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# getting the instances with max and the min price
df[(df["horsepower"] == df["horsepower"].min()) | (df["horsepower"] == df["horsepower"].max())]
# Out:
#    symboling  normalized-losses       make fuel-type aspiration num-of-doors  \
# 17         2                121  chevrolet       gas        std          two
# 46         0                122     jaguar       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  fuel-system  \
# 17  hatchback          fwd           front        88.4  ...         2bbl
# 46      sedan          rwd           front       102.0  ...         mpfi
#
#     bore stroke compression-ratio  horsepower peak-rpm  city-mpg  highway-mpg  \
# 17  2.91   3.03               9.5          48     5100        47           53
# 46  3.54   2.76              11.5         262     5000        13           17
#
#         size  price
# 17   8508.33   5151
# 46  13534.02  36000
#
# [2 rows x 25 columns]

# %% [markdown]
# ### Size

# %%
# As the city-mpg goes up, the price goes down: this indicates a negative direct correlation
# the city-mpg is also seems like a good predictor.
sns.regplot(x="size", y="price", data=df)
# Out:
# <AxesSubplot:xlabel='size', ylabel='price'>

# %%
df[["size","price"]].corr()
# Out:
#            size     price
# size   1.000000  0.737928
# price  0.737928  1.000000

# %%
# looking at the city-mpg data distribution it's so similaire to the highway-mpg also they have a really strong correlation
numerical_plotting(df,"size","size distribution",'')
# Out:
# C:\Users\LENOVO THINKPAD X260\AppData\Roaming\Python\Python38\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df[["size"]].describe().T
# Out:
#       count          mean          std      min       25%      50%      75%  \
# size  201.0  11500.024627  1153.249143  8508.33  10709.72  11314.2  12275.9
#
#            max
# size  14920.77

# %%
df[(df["size"] == df["size"].min()) | (df["size"] == df["size"].max())]
# Out:
#    symboling  normalized-losses           make fuel-type aspiration  \
# 17         2                121      chevrolet       gas        std
# 70         0                122  mercedes-benz       gas        std
#
#    num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# 17          two  hatchback          fwd           front        88.4  ...
# 70         four      sedan          rwd           front       120.9  ...
#
#     fuel-system  bore stroke compression-ratio  horsepower peak-rpm  city-mpg  \
# 17         2bbl  2.91   3.03               9.5          48     5100        47
# 70         mpfi  3.80   3.35               8.0         184     4500        14
#
#     highway-mpg      size  price
# 17           53   8508.33   5151
# 70           16  14920.77  40960
#
# [2 rows x 25 columns]

# %% [markdown]
# ### let's move now the the vars with a negative correlation

# %% [markdown]
# ### highway-mpg

# %%
# As the highway-mpg goes up, the price goes down: this indicates a negative direct correlation
# the highway-mpg is also seems like a good predictor.
sns.regplot(x="highway-mpg", y="price", data=df)
# Out:
# <AxesSubplot:xlabel='highway-mpg', ylabel='price'>

# %%
# the highway-mpg the firs highest negative correlation factor 
df[["highway-mpg","price"]].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %%
# looking at the highway-mpg data distribution
numerical_plotting(df,'highway-mpg','highway-mpg Distribution','')
# Out:
# C:\Users\LENOVO THINKPAD X260\AppData\Roaming\Python\Python38\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df[["highway-mpg"]].describe().T
# Out:
#              count       mean      std   min   25%   50%   75%   max
# highway-mpg  201.0  30.686567  6.81515  16.0  25.0  30.0  34.0  54.0

# %%
# getting the instances with max and the min price
df[(df["highway-mpg"] == df["highway-mpg"].min()) | (df["highway-mpg"] == df["highway-mpg"].max())]
# Out:
#    symboling  normalized-losses           make fuel-type aspiration  \
# 29         2                137          honda       gas        std
# 70         0                122  mercedes-benz       gas        std
# 71         1                122  mercedes-benz       gas        std
#
#    num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# 29          two  hatchback          fwd           front        86.6  ...
# 70         four      sedan          rwd           front       120.9  ...
# 71          two    hardtop          rwd           front       112.0  ...
#
#     fuel-system  bore stroke compression-ratio  horsepower peak-rpm  city-mpg  \
# 29         1bbl  2.91   3.41               9.6          58     4800        49
# 70         mpfi  3.80   3.35               8.0         184     4500        14
# 71         mpfi  3.80   3.35               8.0         184     4500        14
#
#     highway-mpg      size  price
# 29           54   9239.94   6479
# ...

# %% [markdown]
# ### city-mpg

# %%
# As the city-mpg goes up, the price goes down: this indicates a negative direct correlation
# the city-mpg is also seems like a good predictor.
sns.regplot(x="city-mpg", y="price", data=df)
# Out:
# <AxesSubplot:xlabel='city-mpg', ylabel='price'>

# %%
df[["city-mpg","price"]].corr()
# Out:
#           city-mpg     price
# city-mpg  1.000000 -0.686571
# price    -0.686571  1.000000

# %%
# looking at the city-mpg data distribution it's so similaire to the highway-mpg also they have a really strong correlation
numerical_plotting(df,"city-mpg","city-mpg distribution",'')
# Out:
# C:\Users\LENOVO THINKPAD X260\AppData\Roaming\Python\Python38\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df[["city-mpg"]].describe().T
# Out:
#           count       mean      std   min   25%   50%   75%   max
# city-mpg  201.0  25.179104  6.42322  13.0  19.0  24.0  30.0  49.0

# %%
df[(df["city-mpg"] == df["city-mpg"].min()) | (df["city-mpg"] == df["city-mpg"].max())]
# Out:
#    symboling  normalized-losses    make fuel-type aspiration num-of-doors  \
# 29         2                137   honda       gas        std          two
# 46         0                122  jaguar       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  fuel-system  \
# 29  hatchback          fwd           front        86.6  ...         1bbl
# 46      sedan          rwd           front       102.0  ...         mpfi
#
#     bore stroke compression-ratio  horsepower peak-rpm  city-mpg  highway-mpg  \
# 29  2.91   3.41               9.6          58     4800        49           54
# 46  3.54   2.76              11.5         262     5000        13           17
#
#         size  price
# 29   9239.94   6479
# 46  13534.02  36000
#
# [2 rows x 25 columns]

# %%
# let's see the relation between the city-mpg and highway-mpg
sns.regplot(x="city-mpg", y="highway-mpg", data=df)
# Out:
# <AxesSubplot:xlabel='city-mpg', ylabel='highway-mpg'>

# %%
# since they have the same distribution and have almost perfect correlation with a diagonal line
# we can do some feature engineering on it and create a new variable that represent theme both
df = df.assign(city_highway_mpg=(df["city-mpg"]+df["highway-mpg"])/2)
df = df[df.columns[:-2].to_list()+['city_highway_mpg','price']]
df.drop(['city-mpg', 'highway-mpg'], axis=1, inplace = True)

# %%
# let's make sure that have the almost the same correlation 
# note that city-mpg have -0.69  and highway-mpg -0.7
df[['city_highway_mpg','price']].corr()
# Out:
#                   city_highway_mpg     price
# city_highway_mpg          1.000000 -0.700811
# price                    -0.700811  1.000000

# %%
#### perfect it have the

# %% [markdown]
# ## we are moving now to te categorical variables

# %%
# let's take a look again for the categorical object
df.describe(include=['object'])
# Out:
#         symboling    make fuel-type aspiration num-of-doors body-style  \
# count         201     201       201        201          201        201
# unique          6      22         2          2            2          5
# top             0  toyota       gas        std         four      sedan
# freq           65      32       181        165          115         94
#
#        drive-wheels engine-location engine-type num-of-cylinders fuel-system
# count           201             201         201              201         201
# unique            3               2           6                7           8
# top             fwd           front         ohc             four        mpfi
# freq            118             198         145              157          92

# %%
# this function is responsible for plotting the total count for each categorie
def count_categorical_plotting(df, col_name, title, rotate):
    fig, ax = plt.subplots(figsize=(10,7))
    ax = sns.countplot(x=col_name, data=df)
    ax.bar_label(container = ax.containers[0])
    ax.set_xticklabels(ax.get_xticklabels(),fontsize=12)
    
    if rotate:
        fig.set_size_inches(15, 11, forward=True)
        plt.xticks(rotation=90,fontsize=12)
        
    ax.set_xlabel(col_name, fontsize=16)
    ax.set_ylabel("count", fontsize=16)
    ax.set_title(title, fontsize = 20)
    plt.show()

# this function is responsible for plotting the average price for each categorie
def mean_categorical_plotting(df, col_name, title):
    fig, ax = plt.subplots(figsize=(10,7))
    ax = sns.barplot(x=df.index,y = "price", data=df)
    ax.bar_label(ax.containers[0])
    ax.set_xticklabels(ax.get_xticklabels())
    ax.set_title(title,fontsize=18)
    plt.show()
    
# this function is responsible for plotting the boxplot to see the distribution
def boxplot_categorical_plotting(df, col_name, title):
    fig, ax = plt.subplots(figsize=(10,7))
    ax = sns.boxplot(x=col_name, y = "price", data=df)
    ax.set_xticklabels(ax.get_xticklabels())
    ax.set_title(title,fontsize=18)
    plt.show()

# %% [markdown]
# ### make

# %%
count_categorical_plotting(df,"make","total count per Brand", True)

# %% [markdown]
# ### Symboling

# %%
count_categorical_plotting(df,"symboling","total count per symboling", False)

# %%
mean_categorical_plotting(df.groupby("symboling").mean()[["price"]],"symboling","average price for each symboling")

# %%
boxplot_categorical_plotting(df[["price","symboling"]],"symboling","average price for each symboling")

# %%
df.groupby("symboling").mean()[["price"]].sort_values(by='price',ascending=False)
# Out:
#                   price
# symboling
# -1         17330.681818
#  3         17221.296296
# -2         15781.666667
#  0         14397.092308
#  2         10109.281250
#  1          9648.653846

# %% [markdown]
# ### fuel-type

# %%
count_categorical_plotting(df,"fuel-type","total count per fuel-type",False)

# %%
# there is to much overlaping here between the this two fuel-type. so i don't think is a good predictor 
boxplot_categorical_plotting(df[["price","fuel-type"]],"fuel-type","average price for each fuel-type")

# %%
df.groupby("fuel-type").mean()[["price"]].sort_values(by='price',ascending=False)
# Out:
#                  price
# fuel-type
# diesel     15838.15000
# gas        12916.40884

# %% [markdown]
# ### aspiration

# %%
count_categorical_plotting(df,"aspiration","total count per aspiration",False)

# %%
mean_categorical_plotting(df.groupby("aspiration").mean()[["price"]],"aspiration","average price for each aspiration type")

# %%
boxplot_categorical_plotting(df[["price","aspiration"]],"aspiration","average price for each aspiration type")

# %% [markdown]
# ### num-of-doors

# %%
count_categorical_plotting(df,"num-of-doors","total count per num-of-doors",False)

# %%
mean_categorical_plotting(df.groupby("num-of-doors").mean()[["price"]],"num-of-doors","average price for each num-of-doors")

# %%
boxplot_categorical_plotting(df[["price","num-of-doors"]],"num-of-doors","average price for each num-of-doors")

# %%
df.describe(include=['object'])
# Out:
#         symboling    make fuel-type aspiration num-of-doors body-style  \
# count         201     201       201        201          201        201
# unique          6      22         2          2            2          5
# top             0  toyota       gas        std         four      sedan
# freq           65      32       181        165          115         94
#
#        drive-wheels engine-location engine-type num-of-cylinders fuel-system
# count           201             201         201              201         201
# unique            3               2           6                7           8
# top             fwd           front         ohc             four        mpfi
# freq            118             198         145              157          92

# %% [markdown]
# ### body-style

# %%
count_categorical_plotting(df,"body-style","total count per body-style",False)

# %%
mean_categorical_plotting(df.groupby("body-style").mean()[["price"]],"body_style","average price for each body-style")

# %%
boxplot_categorical_plotting(df[["price","body-style"]],"body-style","average price for each body-style")

# %%
df.groupby("body-style").mean()[["price"]].sort_values(by='price',ascending=False)
# Out:
#                     price
# body-style
# hardtop      22208.500000
# convertible  21890.500000
# sedan        14459.755319
# wagon        12371.960000
# hatchback     9957.441176

# %% [markdown]
# ### drive-wheels

# %%
count_categorical_plotting(df,"drive-wheels","total count per drive-wheels",False)

# %%
mean_categorical_plotting(df.groupby("drive-wheels").mean()[["price"]],"drive-wheels","average price for each drive-wheels")

# %%
boxplot_categorical_plotting(df[["price","drive-wheels"]],"drive-wheels","average price for each drive-wheels")

# %%
df.groupby("drive-wheels").mean()[["price"]].sort_values(by='price',ascending=False)
# Out:
#                      price
# drive-wheels
# rwd           19757.613333
# 4wd           10241.000000
# fwd            9244.779661

# %% [markdown]
# ### engine-location

# %%
count_categorical_plotting(df,"engine-location","total count per engine-location",False)

# %%
mean_categorical_plotting(df.groupby("engine-location").mean()[["price"]],"engine-location","average price for each engine-location")

# %%
boxplot_categorical_plotting(df[["price","engine-location"]],"engine-location","average price for each engine-location")

# %%
df.groupby("engine-location").mean()[["price"]].sort_values(by='price',ascending=False)
# Out:
#                         price
# engine-location
# rear             34528.000000
# front            12884.085859

# %% [markdown]
# ### engine-type

# %%
count_categorical_plotting(df,"engine-type","total count per engine-type",False)

# %%
mean_categorical_plotting(df.groupby("engine-type").mean()[["price"]],"engine-location","average price for each engine-type")

# %%
boxplot_categorical_plotting(df[["price","engine-type"]],"engine-type","average price for each engine-type")

# %%
df.groupby("engine-type").mean()[["price"]].sort_values(by='price',ascending=False)
# Out:
#                     price
# engine-type
# ohcv         25098.384615
# dohc         18116.416667
# l            14627.583333
# ohcf         13738.600000
# rotor        13020.000000
# ohc          11567.358621

# %% [markdown]
# ### num-of-cylinders

# %%
count_categorical_plotting(df,"num-of-cylinders","total count per num-of-cylinders",False)

# %%
mean_categorical_plotting(df.groupby("num-of-cylinders").mean()[["price"]],"num-of-cylinders","average price for each num-of-cylinders")

# %%
boxplot_categorical_plotting(df[["price","num-of-cylinders"]],"num-of-cylinders","average price for each num-of-cylinders")

# %%
df.groupby("num-of-cylinders").mean()[["price"]].sort_values(by='price',ascending=False)
# Out:
#                          price
# num-of-cylinders
# eight             38900.000000
# twelve            36000.000000
# six               23671.833333
# five              22007.600000
# two               13020.000000
# four              10303.197452
# three              5151.000000

# %% [markdown]
# ### fuel-system

# %%
count_categorical_plotting(df,"fuel-system","total count per fuel-system",False)

# %%
mean_categorical_plotting(df.groupby("fuel-system").mean()[["price"]],"fuel-system","average price for each fuel-system")

# %%
boxplot_categorical_plotting(df[["price","fuel-system"]],"fuel-system","average price for each fuel-system")

# %%
df.groupby("fuel-system").mean()[["price"]].sort_values(by='price',ascending=False)
# Out:
#                     price
# fuel-system
# mpfi         17605.141304
# idi          15838.150000
# mfi          12964.000000
# 4bbl         12145.000000
# spfi         11048.000000
# spdi         10990.444444
# 1bbl          7555.545455
# 2bbl          7433.203125

# %% [markdown]
# ## Now let's see the significance of the correlation

# %%
from scipy import stats

# %%
def eta_square(df,feature_name):
    
    ss_within = 0
    grand_mean = 0
    for name in df[feature_name].unique():
        df_categorie = df[['price']][df[feature_name]==name]
        ss_within += df_categorie.var()*(df_categorie.shape[0]-1)
        grand_mean += df_categorie.mean()
        
    grand_mean /= len(df[feature_name].unique())
    
    ss_between = 0
    for name in df[feature_name].unique():
        df_categorie = df[['price']][df[feature_name]==name]
        ss_between += df_categorie.shape[0]*((df_categorie.mean() - grand_mean)**2)
          
    ss_total = ss_between + ss_within
    print(f"the grand mean is {grand_mean[0]}")
    print(f"ss_within = {ss_within[0]}   ,   ss_between = {ss_between[0]}")
    print(f"the eta squred {(ss_between/ss_total*100)[0]} %")

# %%
def f_critical(df,feature_name):
    k = len(df[feature_name].unique())
    dfn = k-1
    dfd = df.shape[0]-k
    f_critical = stats.f.ppf(1-.005, dfn, dfd)
    print(f"df_within = {dfn}   ,   df_between = {dfd}")
    print(f"f_critical {f_critical}")

# %% [markdown]
# # Categorical variables

# %% [markdown]
# ### Aspiration

# %%
grouped_test2=df[['aspiration', 'price']].groupby(['aspiration'])
grouped_test2.groups.keys()
# Out:
# dict_keys(['std', 'turbo'])

# %%
f_val, p_val = stats.f_oneway(grouped_test2.get_group('std')['price'], grouped_test2.get_group('turbo')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 6.631286341771227 , P = 0.010745853841804088

# %% [markdown]
# ### Conclusion
# since the significanse level is > 0.001 we can't reject the Null hypothesis. so i think this feature will add no remarquable impact on the dependent feature (price)

# %% [markdown]
# ### Symboling

# %%
grouped_test2=df[['symboling', 'price']].groupby(['symboling'])
grouped_test2.groups.keys()
# Out:
# dict_keys([-2, -1, 0, 1, 2, 3])

# %%
minus_two = grouped_test2.get_group(-2)['price']
minus_one = grouped_test2.get_group(-1)['price']
zero = grouped_test2.get_group(0)['price']
one = grouped_test2.get_group(1)['price']
two = grouped_test2.get_group(2)['price']
three = grouped_test2.get_group(3)['price']

# %%
f_val, p_val = stats.f_oneway(minus_two, minus_one, zero, one, two, three)  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 6.847986667874624 , P = 6.556745663768536e-06

# %%
f_critical(df,"symboling")
# Out:
# df_within = 5   ,   df_between = 195
# f_critical 3.4704231074920866

# %%
eta_square(df,"symboling")
# Out:
# the grand mean is 14081.445364165156
# ss_within = 10744544540.75316   ,   ss_between = 2040278273.764802
# the eta squred 15.958596402665345 %

# %% [markdown]
# ### Conclusion
# since the significanse level is < 0.001 we can reject the Null hypothesis and the f-statistical > f-critical value.but the eta square which shows the impact of this feature on the predicted feature is quit low.

# %% [markdown]
# ### Body-style

# %%
grouped_test2=df[['body-style', 'price']].groupby(['body-style'])
grouped_test2.groups.keys()
# Out:
# dict_keys(['convertible', 'hardtop', 'hatchback', 'sedan', 'wagon'])

# %%
convertible = grouped_test2.get_group('convertible')['price']
hardtop = grouped_test2.get_group('hardtop')['price']
hatchback = grouped_test2.get_group('hatchback')['price']
sedan = grouped_test2.get_group('sedan')['price']
wagon = grouped_test2.get_group('wagon')['price']

# %%
f_val, p_val = stats.f_oneway(convertible, hardtop, hatchback, sedan, wagon)  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 9.12875185470821 , P = 8.779795237614595e-07

# %%
f_critical(df,'body-style')
# Out:
# df_within = 4   ,   df_between = 196
# f_critical 3.8393650862408557

# %%
eta_square(df,'body-style')
# Out:
# the grand mean is 16177.631299123905
# ss_within = 10647527118.59705   ,   ss_between = 3757245813.95765
# the eta squred 26.08333940111126 %

# %% [markdown]
# ### Conclusion
# since the significanse level is < 0.001 we can reject the Null hypothesis and the f-statistical > f-critical value.but the eta square which shows the impact of this feature on the predicted feature is quit low.

# %% [markdown]
# ### fuel-type

# %%
grouped_test2=df[['fuel-type', 'price']].groupby(['fuel-type'])
grouped_test2.groups.keys()
# Out:
# dict_keys(['diesel', 'gas'])

# %%
f_val, p_val = stats.f_oneway(grouped_test2.get_group('diesel')['price'], grouped_test2.get_group('gas')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 2.4520196354787864 , P = 0.11896254438091516

# %% [markdown]
# ### Conclusion
# since the significanse level is > 0.001 we can't reject the Null hypothesis.

# %% [markdown]
# ### engine-location

# %%
grouped_test2=df[['engine-location', 'price']].groupby(['engine-location'])
grouped_test2.groups.keys()
# Out:
# dict_keys(['front', 'rear'])

# %%
f_val, p_val = stats.f_oneway(grouped_test2.get_group('front')['price'], grouped_test2.get_group('rear')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 24.495550318865693 , P = 1.583490019777699e-06

# %%
f_critical(df,'engine-location')
# Out:
# df_within = 1   ,   df_between = 199
# f_critical 8.058067393914964

# %%
eta_square(df,'engine-location')
# Out:
# the grand mean is 23706.04292929293
# ss_within = 11246771407.540405   ,   ss_between = 23540065722.88558
# the eta squred 67.66946254592511 %

# %% [markdown]
# ### Conclusion
# since the significanse level is < 0.001 we can reject the Null hypothesis and the f-statistical > f-critical value.and also the eta square which shows is moderatlely strong.

# %% [markdown]
# ### engine-type

# %%
grouped_test2=df[['engine-type', 'price']].groupby(['engine-type'])
grouped_test2.groups.keys()
# Out:
# dict_keys(['dohc', 'l', 'ohc', 'ohcf', 'ohcv', 'rotor'])

# %%
dohc = grouped_test2.get_group('dohc')['price']
l = grouped_test2.get_group('l')['price']
ohc = grouped_test2.get_group('ohc')['price']
ohcf = grouped_test2.get_group('ohcf')['price']
ohcv = grouped_test2.get_group('ohcv')['price']
rotor = grouped_test2.get_group('rotor')['price']

# %%
f_val, p_val = stats.f_oneway(dohc,l,ohc,ohcf,ohcv,rotor)  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 9.845110955850451 , P = 2.0865492749735665e-08

# %% [markdown]
# ### Conclusion
# since the significanse level is > 0.001 we can't reject the Null hypothesis.

# %% [markdown]
# ### drive-wheels

# %%
grouped_test2=df[['drive-wheels', 'price']].groupby(['drive-wheels'])
grouped_test2.groups.keys()
# Out:
# dict_keys(['4wd', 'fwd', 'rwd'])

# %%
f_val, p_val = stats.f_oneway(grouped_test2.get_group('fwd')['price'], grouped_test2.get_group('rwd')['price'], grouped_test2.get_group('4wd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 67.95406500780399 , P = 3.3945443577151245e-23

# %%
f_critical(df,'drive-wheels')
# Out:
# df_within = 2   ,   df_between = 198
# f_critical 5.442659446135755

# %%
eta_square(df,'drive-wheels')
# Out:
# the grand mean is 13081.130998116763
# ss_within = 7490000894.057854   ,   ss_between = 5144362787.262897
# the eta squred 40.71722895604603 %

# %% [markdown]
# ### Conclusion
# since the significanse level is < 0.001 we can reject the Null hypothesis and the f-statistical > f-critical value. the eta square shows a moderate impact on the predicted feature.

# %% [markdown]
# ### num-of-cylinders

# %%
grouped_test2=df[['num-of-cylinders', 'price']].groupby(['num-of-cylinders'])
grouped_test2.groups.keys()
# Out:
# dict_keys(['eight', 'five', 'four', 'six', 'three', 'twelve', 'two'])

# %%
eight = grouped_test2.get_group('eight')['price']
five = grouped_test2.get_group('five')['price']
four = grouped_test2.get_group('four')['price']
six = grouped_test2.get_group('six')['price']
three = grouped_test2.get_group('three')['price']
twelve = grouped_test2.get_group('twelve')['price']
two = grouped_test2.get_group('two')['price']

# %%
f_val, p_val = stats.f_oneway(eight,five,four,six,three,twelve,two)  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 54.94365304663237 , P = 2.870144542812576e-39

# %%
f_critical(df,'num-of-cylinders')
# Out:
# df_within = 6   ,   df_between = 194
# f_critical 3.20955615409879

# %%
eta_square(df,'num-of-cylinders')
# Out:
# the grand mean is 21293.375826508945
# ss_within = nan   ,   ss_between = 21094590795.3619
# the eta squred nan %

# %% [markdown]
# # Now for the numerical variables

# %%
df.corr()
# Out:
#                    normalized-losses  wheel-base    height  curb-weight  \
# normalized-losses           1.000000   -0.056661 -0.373737     0.099404
# wheel-base                 -0.056661    1.000000  0.590742     0.782097
# height                     -0.373737    0.590742  1.000000     0.307581
# curb-weight                 0.099404    0.782097  0.307581     1.000000
# engine-size                 0.112360    0.572027  0.074694     0.849072
# bore                       -0.029862    0.493244  0.180449     0.644060
# stroke                      0.126034   -0.079330 -0.244270    -0.036691
# compression-ratio          -0.114713    0.250313  0.259737     0.156433
# horsepower                  0.217300    0.371178 -0.087001     0.757981
# peak-rpm                    0.239544   -0.360301 -0.309971    -0.279360
# size                        0.040388    0.889137  0.449278     0.905256
# city_highway_mpg           -0.204239   -0.511617 -0.078672    -0.778341
# ...

# %% [markdown]
# ## Marque
# We are going to study only the variables that have > 0.55 AND < -0.55 correlation with the dependt feature

# %% [markdown]
# ### wheel-base

# %%
pearson_coef, p_value = stats.pearsonr(df['wheel-base'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.584641822265508  with a P-value of P =  8.076488270733218e-20

# %% [markdown]
# ### Conclusion
# Since the p-value is < 0.001, the correlation between wheel-base and price is statistically significant, and the linear relationship is moderate (~0.585).

# %% [markdown]
# ### curb-wieght

# %%
pearson_coef, p_value = stats.pearsonr(df['curb-weight'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8344145257702843  with a P-value of P =  2.189577238894065e-53

# %% [markdown]
# ### Conclusion
# Since the p-value is < 0.001, the correlation between curb-weight and price is statistically significant, and the linear relationship is Strong (~0.834).

# %% [markdown]
# ### engine-size

# %%
pearson_coef, p_value = stats.pearsonr(df['engine-size'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8723351674455182  with a P-value of P =  9.265491622200232e-64

# %% [markdown]
# ### Conclusion
# Since the p-value is < 0.001, the correlation between engine-size and price is statistically significant, and the linear relationship is extremly strong (~0.872).

# %% [markdown]
# ### horsepower

# %%
pearson_coef, p_value = stats.pearsonr(df['horsepower'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8096068016571054  with a P-value of P =  6.273536270650504e-48

# %% [markdown]
# ### Conclusion
# Since the p-value is < 0.001, the correlation between horsepower and price is statistically significant, and the linear relationship is quite strong (~0.809, close to 1).

# %% [markdown]
# ### city_highway_mpg

# %%
pearson_coef, p_value = stats.pearsonr(df['city_highway_mpg'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.7008108129035969  with a P-value of P =  5.140975617823303e-31

# %% [markdown]
# ### Conclusion
# Since the p-value is < 0.001, the correlation between city_highway_mpg and price is statistically significant, and the linear relationship is moderately strong and it's negative (~ -0.7).

# %% [markdown]
# ### Size

# %%
pearson_coef, p_value = stats.pearsonr(df['size'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.7379277694176107  with a P-value of P =  7.910637348102228e-36

# %% [markdown]
# ### Conclusion
# Since the p-value is < 0.001, the correlation between size and price is statistically significant, and the linear relationship is moderately strong (~ 0.738).

# %% [markdown]
# ## Finaly
# We now have a better idea of what our data looks like and which variables are important to take into account when predicting the car price. We have narrowed it down to the following variables:
#
# Numerical features :
# <ul>
#     <li>Curb-weight</li>
#     <li>Engine-size</li>
#     <li>Horsepower</li>
#     <li>City_Highway_mpg</li>
#     <li>Wheel-base</li>
#     <li>size</li>
# </ul>
#
# categorical features :
#
# <ul>
#     <li>engine-location</li>
#     <li>drive-wheels</li>
# </ul>

# %%
columns = ["curb-weight", "engine-size","horsepower","city_highway_mpg","wheel-base",
           "size", "engine-location","drive-wheels","price"]
df = df[columns]

# %%
df = pd.get_dummies(df, columns=["engine-location","drive-wheels"], drop_first=True)
df2 = df.drop(['price'],axis = 1)
df = df2.assign(price=df["price"])

df.head()
# Out:
#    curb-weight  engine-size  horsepower  city_highway_mpg  wheel-base  \
# 0         2548          130         111              24.0        88.6
# 1         2548          130         111              24.0        88.6
# 2         2823          152         154              22.5        94.5
# 3         2337          109         102              27.0        99.8
# 4         2824          136         115              20.0        99.4
#
#        size  engine-location_rear  drive-wheels_fwd  drive-wheels_rwd  price
# 0  10820.08                     0                 0                 1  13495
# 1  10820.08                     0                 0                 1  16500
# 2  11213.60                     0                 0                 1  16500
# 3  11690.92                     0                 1                 0  13950
# 4  11726.24                     0                 0                 0  17450

# %%
df.to_csv('final_analysis.csv')

# %%
import pickle 

with open('columns.pkl','wb') as file:
    pickle.dump(df.columns.to_list())

# %%
df.columns.to_list()
# Out:
# ['curb-weight',
#  'engine-size',
#  'horsepower',
#  'city_highway_mpg',
#  'wheel-base',
#  'size',
#  'engine-location_rear',
#  'drive-wheels_fwd',
#  'drive-wheels_rwd',
#  'price']

# %%
data = {"curb-weight" : 2548, "engine-size" : 130, "horsepower" : 111,"city_highway_mpg" : 24.0,"wheel-base" : 88.6,
         "size" : 10820.08, "engine-location" : "Front", "drive-wheels" : "Rwd", "price" : 13495.0 }


data2 = pd.DataFrame(data = data, index=[0])
data2
# Out:
#    curb-weight  engine-size  horsepower  city_highway_mpg  wheel-base  \
# 0         2548          130         111              24.0        88.6
#
#        size engine-location drive-wheels    price
# 0  10820.08           Front          Rwd  13495.0

# %%
data2 = pd.get_dummies(data2, columns=["engine-location","drive-wheels"])
data2.dtypes
# Out:
# curb-weight                int64
# engine-size                int64
# horsepower                 int64
# city_highway_mpg         float64
# wheel-base               float64
# size                     float64
# price                    float64
# engine-location_Front      uint8
# drive-wheels_Rwd           uint8
# dtype: object
